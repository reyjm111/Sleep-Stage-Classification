# %%
from file_conversion import file_conversion
import numpy as np

# %%
path = "/Users/reymendoza/Desktop/sleep_files"
X, y, groups = file_conversion(path)
# Out:
# Processing: sub-001_ses-001_task-sleep_acq-PSG_eeg.set
# Reading /Users/reymendoza/Desktop/sleep_files/sub-001/ses-001/sub-001_ses-001_task-sleep_acq-PSG_eeg.fdt
# Reading 0 ... 14255559  =      0.000 ... 28511.118 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 5501 samples (11.002 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 3301 samples (6.602 s)
#
# Processing: sub-002_ses-001_task-sleep_acq-PSG_eeg.set
# Reading /Users/reymendoza/Desktop/sleep_files/sub-002/ses-001/sub-002_ses-001_task-sleep_acq-PSG_eeg.fdt
# Reading 0 ... 15034689  =      0.000 ... 30069.378 secs...
# Failed on /Users/reymendoza/Desktop/sleep_files/sub-002/ses-001: Incorrect number of samples (0 != 25000000), please report this error to MNE-Python developers
# Processing: sub-003_ses-001_task-sleep_acq-PSG_eeg.set
# Reading /Users/reymendoza/Desktop/sleep_files/sub-003/ses-001/sub-003_ses-001_task-sleep_acq-PSG_eeg.fdt
# Reading 0 ... 16048779  =      0.000 ... 32097.558 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 5501 samples (11.002 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 3301 samples (6.602 s)
#
# Processing: sub-004_ses-001_task-sleep_acq-PSG_eeg.set
# Reading /Users/reymendoza/Desktop/sleep_files/sub-004/ses-001/sub-004_ses-001_task-sleep_acq-PSG_eeg.fdt
# Reading 0 ... 15151949  =      0.000 ... 30303.898 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 5501 samples (11.002 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 3301 samples (6.602 s)
#
# Processing: sub-005_ses-001_task-sleep_acq-PSG_eeg.set
# Reading /Users/reymendoza/Desktop/sleep_files/sub-005/ses-001/sub-005_ses-001_task-sleep_acq-PSG_eeg.fdt
# Reading 0 ... 15940539  =      0.000 ... 31881.078 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 5501 samples (11.002 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 3301 samples (6.602 s)
#
# Processing: sub-006_ses-001_task-sleep_acq-PSG_eeg.set
# Reading /Users/reymendoza/Desktop/sleep_files/sub-006/ses-001/sub-006_ses-001_task-sleep_acq-PSG_eeg.fdt
# Reading 0 ... 14505699  =      0.000 ... 29011.398 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 5501 samples (11.002 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 3301 samples (6.602 s)
#
# Processing: sub-007_ses-001_task-sleep_acq-PSG_eeg.set
# Reading /Users/reymendoza/Desktop/sleep_files/sub-007/ses-001/sub-007_ses-001_task-sleep_acq-PSG_eeg.fdt
# Reading 0 ... 15612519  =      0.000 ... 31225.038 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 5501 samples (11.002 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 3301 samples (6.602 s)
#
# Processing: sub-008_ses-001_task-sleep_acq-PSG_eeg.set
# Reading /Users/reymendoza/Desktop/sleep_files/sub-008/ses-001/sub-008_ses-001_task-sleep_acq-PSG_eeg.fdt
# Reading 0 ... 15275809  =      0.000 ... 30551.618 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.3 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.30
# - Lower transition bandwidth: 0.30 Hz (-6 dB cutoff frequency: 0.15 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 5501 samples (11.002 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 3301 samples (6.602 s)

# %%
#np.savez_compressed("sleep_dataset.npz", X=X, y=y, groups=groups)

data = np.load("/Users/reymendoza/Developer/Sleep-Stage-Classification/preprocessing/sleep_dataset.npz", allow_pickle=True)
X = data["X"]
y = data["y"]
groups = data["groups"]

print(X.shape, y.shape, groups.shape)
# Out:
# (7054, 12, 6000) (7054,) (7054,)
